# %%
https://github.com/lovit/soynlp/blob/master/tutorials/nounextractor-v1_usage.ipynb
    https://wikidocs.net/4231

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import urllib.request
from collections import Counter
from konlpy import init_jvm
from konlpy.tag import Mecab
from konlpy.tag import Hannanum, Okt
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
#print('konlpy version = %s' % konlpy.__version__)
# urllib.request.urlretrieve("https://raw.githubusercontent.com/bab2min/corpus/master/sentiment/naver_shopping.txt",
#                            filename="ratings_total.txt")

#news = pd.read_table
a=[]
total_data = pd.read_table('F:/news/newss/news1.txt', names=['news'])
print(len(total_data))
for i in range(len(total_data)):
    #print(total_data.news.values[i])
    print(hannanum.nouns(total_data.news.values[i]))
    print(hannanum.morphs(total_data.news.values[i]))
    a.append(hannanum.pos(total_data.news.values[i]))
# Out:
# 8
# ['삼성디스플레이', 'OLED(올레드)', '노트북', '‘다크', '모드’', '적용', '디스플레이', '소비전력', '25', '수', '6일']
# ['삼성디스플레이', '가', 'OLED(올레드)', '노트북', '에서', '‘다크', '모드’', '를', '적용', '하', '면', '디스플레이', '소비전력', '25', '%', '를', '아끼', 'ㄹ', '수', '있', '다', '고', '6일', '밝히', '었다', '.']
# ['삼성디스플레이', '업계', '노트북', '배터리', '성능', '평가', '때', '주', '사용', '기준', '‘모바', '마크', '2018’1)', '시나리오', '노트북', '배터리', '사용시간', '측정', '결과', '화이트', '모드', '9.', '9시간', '다크', '모드', '11시간']
# ['삼성디스플레이', '가', 'IT', '업계', '에서', '노트북', '의', '배터리', '성능', '을', '평가', '하', 'ㄹ', '때', '주', '로', '사용', '하', '는', '기준', '이', 'ㄴ', '‘모바', '이', 'ㄹ', '마크', '2018’1)', '시나리오', '에', '따르', '아', 'OLED', '노트북', '의', '배터리', '사용시간', '을', '측정', '하', 'ㄴ', '결과', ',', '화이트', '모드', '에서는', '9.', '9시간', ',', '다크', '모드', '에서는', '11시간', '으로', '나타나', '아다', '.']
# ['다크', '모드', '적용', '때', '화면', '구성', '전체', '픽셀', '중', '작동', '픽셀', '비율', '‘OPR(On', 'Ratio)’', '감소', '디스플레이', '소비전력', '25', '이', '노트북', '사용', '시간', '약', '1시간', '정도']
# ['다크', '모드', '를', '적용', '하', '었을', '때', '화면', '을', '구성', '하', '는', '전체', '픽셀', '중', '작동', '하', '는', '픽셀', '의', '비율', '을', '나타내', '는', '‘OPR(On', 'Pixel', 'Ratio)’', '이', '감소', '하', '면서', '디스플레이', '소비전력', '이', '25', '%', '줄', '었고', ',', '이', '로', '인하', '어', '노트북', '사용', '시간', '은', '약', '1시간', '정도', '늘', '었다', '.']
# ['배터리', '절약', '효과', '디스플레이', '경우', '가능', '삼성디스플레이', '“픽셀', '하나하나', '빛', '픽셀', '방식', '색', '표현', '이때', '일종', '암전', '상태', '때문', '소비전력', '현저', '줄어든다“며', '”반면', '액정표시장치', '검은색', '표현', '때', '백라이트', '이', '‘트루', '블랙’', '표현', '수', '뿐', '다크', '모드', '적용', '소비전력', '않는다”고', '말']
# ['이런', '배터리', '절약', '효과', '는', '디스플레이', '가', 'OLED', '이', 'ㄹ', '경우', '에만', '가능', '하', '다', '.', '삼성디스플레이', '는', '“픽셀', '하나하나', '가', '스스로', '빛', '을', '내', '는', 'OLED', '는', '픽셀', '을', '끌', '는', '방식', '으로', '걸', 'ㅁ', '은', '색', '을', '표현', '하', 'ㄴ데', ',', '이때', '는', '일종', '의', '암전', '상태', '이', '기', '때문', '에', '소비전력', '이', '현저', '하', '게', '줄어든다“며', '”반면', 'LCD', '(', '액정표시장치', ')', '는', '검은색', '을', '표현', '하', 'ㄹ', '때', '도', '백라이트', '는', '항상', '크', '어', '지', '어', '있', '어', '이', '로', '인하', '어', '‘트루', '블랙’', '을', '표현', '하', 'ㄹ', '수', '없', '을', '뿐', '만', '아니', '라', '다크', '모드', '를', '적용', '하', '어도', '소비전력', '이', '떨어지', '지', '않는다”고', '말', '하', '었다', '.']
# ['다크', '모드', '화면', '정보', '바탕', '바꾸는UI(사용자', '환경', '디자인', '‘밝', '화면', '글자’', '대', '‘어두운', '화면', '글자’', '표출']
# ['다크', '모드', '는', '화면', '에서', '정보', '를', '담', '고', '있', '지', '않', '은', '바탕', '을', '어둡', '게', '바꾸는UI(사용자', '환경', ')', '디자인', '이', '다', '.', '‘밝', '은', '화면', '에', '걸', 'ㅁ', '은', '글자’', '대', '이', '시ㄴ', '‘어두운', '화면', '에', '희', 'ㄴ', '글자’', '가', '표출', '되', 'ㄴ다', '.']
# ['애플', '마이크로소프트', '구글,', '어도비', '등', '글로벌', '기업들', '자사', '서비스', '다크', '모드', '지원', '28일', '삼성전자', '윈도우', '설정', '다크', '모드', '기본', '적용', '노트북', '신제품', '‘갤럭시', '북', '프로’', '‘갤럭시', '북', '프로', '360’', '공개']
# ['최근', '애플', ',', '마이크로소프트', ',', '구글,', '어도비', '등', '글로벌', '기업들', '이', '자사', '의', '서비스', '에', '다크', '모드', '를', '앞다투', '어', '지원', '하고', '있', '으며', '지나', 'ㄴ', '28일', '에는', '삼성전자', '가', '윈도우', '설정', '에서', '다크', '모드', '를', '기본', '적용', '하', 'ㄴ', '노트북', '신제품', '‘갤럭시', '북', '프로’', '과', '‘갤럭시', '북', '프로', '360’', '을', '공개', '하', '었다', '.']
# ['백지호', '삼성디스플레이', '중소형', '전략마케팅실장(부사장)', '“스마트폰,', '노트북', '모바', '기기', '휴대성', '저전력', '기술', '중요', '다크', '모드', '문제', '해결', '데', '효과적', '솔루션”이라', '“특히', '다크', '모드', '기', '사용', '블루', '라이트', '감소', '눈', '이롭다”고', '말']
# ['백지호', '삼성디스플레이', '중소형', '전략마케팅실장(부사장)', '은', '“스마트폰,', '노트북', '같', '은', '모바', '이', 'ㄹ', '기기', '의', '휴대성', '을', '높이', '기', '위하', '어서', '는', '저전력', '기술', '이', '중요', '하', 'ㄴ데', 'OLED', '와', '다크', '모드', '가', '이런', '문제', '를', '해결', '하', '는', '데', '효과적', '이', 'ㄴ', '솔루션”이라', '이', '며', '“특히', '다크', '모드', '로', 'IT', '기', '이', '기', '를', '사용', '하', '면', '블루', '라이트', '가', '감소', '하', '어', '눈', '에도', '이롭다”고', '말', '하', '었다', '.']
# ['삼성디스플레이', '올해', '초', '13.', '3형부터', '16형까지', '노트북용', '라인업', '10종', '이상', '확대', '중심', '노트북', '시장', '적극적', '공략', '올해', '비대', '고사양', '수요', '증가', '작년', '대비', '판매량', '5배', '것', '전망']
# ['삼성디스플레이', '는', '올해', '초', '부터', '13.', '3형부터', '16형까지', '노트북용', 'OLED', '라인업', '을', '10종', '이상', '으로', '확대', '하', '어', 'LCD', '중심', '의', '노트북', '시장', '을', '적극적', '으로', '공략', '하고', '있', '으며', '올해', '비대', '이', '면', '및', '고사양', '수요', '증가', '로', '작년', '대비', '판매량', '이', '5배', '가량', '늘', '어', '나', 'ㄹ', '것', '으로', '전망', '하고', '있', '다', '.']

# %%
lenA = []
for i in range(len(a)):
    lenA.append(len(a[i]))
max(lenA)

text=[]

for i in range(len(a)):
    for j in range(lenA[i]):
        if a[i][j][1] == 'N' or a[i][j][1] == 'X':
            text.append(a[i][j][0])
            #a

# %%
negative_word_count = Counter(text)#빈도수 측정
print(negative_word_count.most_common(20))
#a
#len(a)
# Out:
# [('하', 23), ('모드', 9), ('다크', 8), ('노트북', 7), ('삼성디스플레이', 5), ('적용', 4), ('소비전력', 4), ('화면', 4), ('디스플레이', 3), ('배터리', 3), ('때', 3), ('사용', 3), ('픽셀', 3), ('표현', 3), ('25', 2), ('수', 2), ('감소', 2), ('이', 2), ('말', 2), ('글자’', 2)]

# %%
print(a[1][1][1])
print(type(lenA[1]))
# Out:
# J
# <class 'int'>
